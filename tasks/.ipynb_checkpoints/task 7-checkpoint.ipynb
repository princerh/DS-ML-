# %%
import pandas as pd
df_wine = pd.read_csv("wine.csv")
df_wine.head(10)
# Out:
#    Unnamed: 0 item_code                                          item_name  \
# 0           0       AA0                               All items - old base
# 1           1      AA0R  Purchasing power of the consumer dollar - old ...
# 2           2       SA0                                          All items
# 3           3      SA0E                                             Energy
# 4           4     SA0L1                                All items less food
# 5           5    SA0L12                    All items less food and shelter
# 6           6   SA0L12E           All items less food, shelter, and energy
# 7           7  SA0L12E4  All items less food, shelter, energy, and used...
# 8           8    SA0L1E                     All items less food and energy
# 9           9     SA0L2                             All items less shelter
#
#    display_level selectable  sort_sequence
# 0              0          T              2
# 1              0          T            400
# ...

# %%
 print(df_wine.loc[6, 'sort_sequence'])
# Out:
# 363

# %% [markdown]
# ### 1st 10 rows saving as Pickle file

# %%
df2 = df_wine[0:10]
print(df2)
# Out:
#    Unnamed: 0 item_code                                          item_name  \
# 0           0       AA0                               All items - old base
# 1           1      AA0R  Purchasing power of the consumer dollar - old ...
# 2           2       SA0                                          All items
# 3           3      SA0E                                             Energy
# 4           4     SA0L1                                All items less food
# 5           5    SA0L12                    All items less food and shelter
# 6           6   SA0L12E           All items less food, shelter, and energy
# 7           7  SA0L12E4  All items less food, shelter, energy, and used...
# 8           8    SA0L1E                     All items less food and energy
# 9           9     SA0L2                             All items less shelter
#
#    display_level selectable  sort_sequence
# 0              0          T              2
# 1              0          T            400
# ...

# %%
df2.to_pickle("datasets/first10Wine.pkl")

# %%
finalPickle = pd.read_pickle("datasets/first10Wine.pkl")
finalPickle
# Out:
#    Unnamed: 0 item_code                                          item_name  \
# 0           0       AA0                               All items - old base
# 1           1      AA0R  Purchasing power of the consumer dollar - old ...
# 2           2       SA0                                          All items
# 3           3      SA0E                                             Energy
# 4           4     SA0L1                                All items less food
# 5           5    SA0L12                    All items less food and shelter
# 6           6   SA0L12E           All items less food, shelter, and energy
# 7           7  SA0L12E4  All items less food, shelter, energy, and used...
# 8           8    SA0L1E                     All items less food and energy
# 9           9     SA0L2                             All items less shelter
#
#    display_level selectable  sort_sequence
# 0              0          T              2
# 1              0          T            400
# ...

# %%
finalPickle.to_csv("datasets/first10Wine.csv")

# %%
read_wine = pd.read_csv("datasets/first10Wine.csv")
read_wine
# Out:
#    Unnamed: 0.1  Unnamed: 0 item_code  \
# 0             0           0       AA0
# 1             1           1      AA0R
# 2             2           2       SA0
# 3             3           3      SA0E
# 4             4           4     SA0L1
# 5             5           5    SA0L12
# 6             6           6   SA0L12E
# 7             7           7  SA0L12E4
# 8             8           8    SA0L1E
# 9             9           9     SA0L2
#
#                                            item_name  display_level  \
# 0                               All items - old base              0
# 1  Purchasing power of the consumer dollar - old ...              0
# 2                                          All items              0
# 3                                             Energy              1
# 4                                All items less food              1
# 5                    All items less food and shelter              1
# ...
